# %%
import re
import os, sys
from pathlib import Path
import json
import logging
import tomllib

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from rich import print, pretty, inspect
from rich.console import Console

# %%
console = Console()
console.print("hello", style = "bold white")
# Out:
# hello

# %%
def init_logger(log_level):
    """Initialize a logger instance"""
    logger = logging.getLogger(__name__)
    logger.setLevel(log_level)
    console_handler = logging.StreamHandler()
    console_handler.setLevel(log_level)
    FORMAT = "[%(levelname)s][%(asctime)s][%(filename)s:%(lineno)s - %(funcName)10s() ] %(message)s"
    formatter = logging.Formatter(FORMAT)
    console_handler.setFormatter(formatter)
    logger.addHandler(console_handler)
    return logger

lg = init_logger(logging.INFO)

# %% [markdown]
# ### 0. Extract All Lines Modifying ```this_block```
# Example wrapper file used for dev: [casper_wb_fft_config.m](https://github.com/talonmyburgh/casper_dspdevel/blob/a8b6f3d9311d7f9579a6eb7015d4d549fece36fe/wrappers/simulink/casper_wb_fft_config.m)
#
# Wei Liu's example SciLab port for ```casper_wb_fft_config.m```:
# 1. JSON: [wbfft.json](https://github.com/liuweiseu/mlib_devel/blob/c74c7bae6b34bd3d8231a78a75955ab2a48cf24e/scilab_library/scilab_blocks/casper_dsp/wbfft.json)
# 2. SciLab: [wbfft.sci](https://github.com/liuweiseu/mlib_devel/blob/c74c7bae6b34bd3d8231a78a75955ab2a48cf24e/scilab_library/scilab_blocks/casper_dsp/wbfft.sci)
# 3. Python: [wbfft.py](https://github.com/liuweiseu/mlib_devel/blob/c74c7bae6b34bd3d8231a78a75955ab2a48cf24e/scilab_library/dsp_blocks/wbfft.py)

# %%
wrappers_root = Path("simulink")
scilab_translations_root = Path("scilab")
os.makedirs(scilab_translations_root, exist_ok=True)

scilab_dsp_root = "casper_dspdevel"

def match_target_lines(target_fpath, line_pat):
    with open(target_fpath, "r") as f:
        d = f.read()
        matches = re.findall(line_pat, d)
        match_line_df = pd.DataFrame(matches)
    return match_line_df

def match_this_block(target_file, this_block_pat="this_block\.(.*)\((.*)\);"):
    this_block_lines_df = match_target_lines(
        target_file,
        line_pat=this_block_pat
    )
    return this_block_lines_df.rename(columns={0: "fn", 1: "args"})

# %%
target_file = "edge_detect_config.m"
target_file = "casper_wb_fft_config.m"
# target_file = "triggered_counter_config.m"

target_fpath_test = wrappers_root / target_file

# %% [markdown]
# ### 5. Build JSON config

# %%
def get_module_name(target_fpath):
    # Load relevant lines
    df = match_this_block(target_fpath)
    fns = ["setEntityName"]
    df = df[df['fn'].isin(fns)]

    name = ""
    if len(df) == 1:
        name_arg = df.iloc[0, 1]
        if isinstance(name_arg, str):
            name = name_arg.strip().replace("'", "")
        else:
            lg.error("Extracted name is not a string.")
    elif len(df) > 1:
        lg.error("No module name detected")
    else:
        lg.error("Multiple module names detected")

    return name



def init_config(target_fpath, tag_prefix="dsp"):
    # Fetch module name
    name = get_module_name(target_fpath_test)
    if name == "":
        lg.error("No name detected: cannot build config")
        return -1

    # Build minimal config
    json_config = {
        "parameters": {
            "keys": [
                "name",
                "fullpath",
                "tag",
            ],
            "values": [
                name,
                "",
                f"{tag_prefix}:{name}",
                
            ]
        }
    }

    # Add generic parameters
    
    default_param_value_template = "UNKNOWN-DEFAULT_{0}" 
    def add_gen_param(param):
        """Note: The config file will explicitly mark unknown defaults.
        A casper expert should fill in these defaults."""
        default_val = default_param_value_template.format(param)
        
        json_config['parameters']['keys'].append(param)
        json_config['parameters']['values'].append(default_val)

    # Add generic parameters
    gen_df = get_generic_params(target_fpath)
    parent_params_df = gen_df.loc[:, ["parent_blk_name", "parent_generic_name"]].dropna()
    parent_params_df["parent_generic_name"] = parent_params_df["parent_generic_name"].str.replace("'", "").str.strip()
    parent_params_df = parent_params_df[parent_params_df['parent_generic_name'] != 'Parent']
    for param in parent_params_df['parent_generic_name']:
        add_gen_param(param)
    
    return json_config

jc = init_config(target_fpath_test)
print(jc)

# %% [markdown]
# ### 6. Build Python DSP class
#
# The code block below will output a module with the following format:
# ```python
# class HDLProcessor(BaseProcessor):
#     def initialize(self):
#         'Initialize method'
#         pass
#     def modify_top(self):
#         'Modify Top method'
#         pass
#     def _generate_hdl_wrapper(self):
#         'Generate Hdl Wrapper method'
#         pass
#
# ```

# %%
"""
DSP Block generator 
"""

import ast

def create_defaultdict_ast(dict_name: str) -> str:
    """Generates AST code to initialize a defaultdict(list) with a given name."""
    
    # Create import statement: from collections import defaultdict
    import_node = ast.ImportFrom(
        module='collections',
        names=[ast.alias(name='defaultdict', asname=None)],
        level=0
    )

    # Create assignment: {dict_name} = defaultdict(list)
    assign_node = ast.Assign(
        targets=[ast.Name(id=dict_name, ctx=ast.Store())],
        value=ast.Call(
            func=ast.Name(id='defaultdict', ctx=ast.Load()),
            args=[ast.Name(id='list', ctx=ast.Load())],
            keywords=[]
        )
    )

    return [import_node, assign_node]


def generate_default_method(method_name):
    """Empty method body (just pass)"""
    method_body = [
        ast.Expr(ast.Constant(value=f"{method_name.replace('_', ' ').title()} method")),
        ast.Pass()
    ]
    
    method = ast.FunctionDef(
        name=method_name,
        args=ast.arguments(
            posonlyargs=[],
            args=[ast.arg(arg='self')],
            kwonlyargs=[],
            kw_defaults=[],
            defaults=[]
        ),
        body=method_body,
        decorator_list=[],
        lineno=1,  # Add default lineno
        end_lineno=1  # Add end_lineno for Python 3.9+
    )
    return method

def generate_class(class_methods: dict, class_name: str, parent_class: str = "DSPBlock") -> str:
    """Generates a Python class with specified structure using AST nodes"""
    # print(class_methods)
    
    methods = []
    for method_name in ['initialize', 'modify_top', '_generate_hdl_wrapper']:
        if method_name in class_methods and isinstance(class_methods[method_name], ast.FunctionDef):
            method = class_methods[method_name]
        else:
            method = generate_default_method(method_name)
        methods.append(method)

    bases = [ast.Name(id=parent_class, ctx=ast.Load())] if parent_class else []

    class_def = ast.ClassDef(
        name=class_name,
        bases=bases,
        keywords=[],
        body=methods,
        decorator_list=[],
        lineno=1,  # Add lineno for class definition
        end_lineno=1
    )

    module = ast.Module(
        body=[
            *create_defaultdict_ast(class_name), # create import library defaultdict with list construct
            class_def
        ],
        type_ignores=[]
    )
    ast.fix_missing_locations(module)  # Critical fix for location attributes
    return ast.unparse(module)

# Example usage:
generated_code = generate_class(
    class_methods={},
    class_name="HDLProcessor"
)
print(generated_code)
# Out:
# from collections import defaultdict
# HDLProcessor = defaultdict(list)
#
# class HDLProcessor(DSPBlock):
#
#     def initialize(self):
#         """Initialize method"""
#         pass
#
#     def modify_top(self):
#         """Modify Top method"""
#         pass
#
#     def _generate_hdl_wrapper(self):
#         """ Generate Hdl Wrapper method"""
#         pass

# %%
"""create code for the initialize method"""

def generate_library_dict_append(class_name, lib_name, path_name):
    # Build the subscript expression: <class_name>_libs[lib_name]
    lib_dict_name = f"{class_name}_libs"
    subscript = ast.Subscript(
        value=ast.Name(id=lib_dict_name, ctx=ast.Load()),
        slice=ast.Name(id=lib_name, ctx=ast.Load()),
        ctx=ast.Load()
    )
    
    # Build the append method call: .append(path_name)
    call = ast.Call(
        func=ast.Attribute(
            value=subscript,
            attr='append',
            ctx=ast.Load()
        ),
        args=[ast.Name(id=path_name, ctx=ast.Load())],
        keywords=[]
    )
    
    # Convert AST to code
    return ast.Expr(call)



def generate_self_dot_func(attr, args):
    dot_call = ast.Call(
        func=ast.Attribute(
            value=ast.Name(id='self', ctx=ast.Load()),  # Represents "self"
            attr=attr,                         # Represents ".add_source"
            ctx=ast.Load()
        ),
        args=args,      # Represents the argument "'example.txt'"
        keywords=[]                                    # No keyword arguments
    )
    return ast.Expr(dot_call)


def generate_initialize_method(class_name:str , dep_df: pd.DataFrame):
    method_name = "initialize"

    # generate instructions to load HDL sources
    add_source_instructions = []
    append_to_library_dict_instructions = []
    for i in range(len(dep_df)):
        lib, fpath = dep_df.loc[:, ["lib", "scilab_fpath"]].iloc[i]
        add_source_expr = generate_self_dot_func(attr='add_source', args=[ast.Constant(value=fpath)])
        append_to_lib_expr= generate_library_dict_append(class_name, lib, f"'{fpath}'")
        
        add_source_instructions.append(add_source_expr)
        append_to_library_dict_instructions.append(append_to_lib_expr)

    

    method_body = [
        ast.Expr(ast.Constant(value=f"{method_name.replace('_', ' ').title()} method")),
        generate_self_dot_func(attr='create_hdl_dir', args=[]),  # create hdl wrappers dir
        *add_source_instructions,
        *append_to_library_dict_instructions
    ]

    # generate method body
    method = ast.FunctionDef(
        name=method_name,
        args=ast.arguments(
            posonlyargs=[],
            args=[ast.arg(arg='self')],
            kwonlyargs=[],
            kw_defaults=[],
            defaults=[]
        ),
        body=method_body,
        decorator_list=[],
        lineno=1,  # Add default lineno
        end_lineno=1  # Add end_lineno for Python 3.9+
    )
    return method

# %%
"""
assemble the final DSP module
"""

def generate_dsp_block(dep_df, jc):
    name_idx = jc['parameters']['keys'].index('name')
    class_name = jc['parameters']['values'][name_idx]
    
    initialize_method = generate_initialize_method(class_name, dep_df)

    class_methods = {
        "initialize": initialize_method,
    }    
    
    # Generate the final module
    generated_code = generate_class(
        class_methods=class_methods,
        class_name=class_name
    )
    
    print(generated_code)
    return generated_code

dep_df = get_file_dependencies(target_fpath_test)
dsp_block_code = generate_dsp_block(dep_df, jc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 25
#      22     return generated_code
#      24 dep_df = get_file_dependencies(target_fpath_test)
# ---> 25 dsp_block_code = generate_dsp_block(dep_df, jc)
#
# Cell In[23], line 6, in generate_dsp_block(dep_df, jc)
#       5 def generate_dsp_block(dep_df, jc):
# ----> 6     name_idx = jc['parameters']['keys'].index('name')
#       7     class_name = jc['parameters']['values'][name_idx]
#       9     initialize_method = generate_initialize_method(class_name, dep_df)
#
# TypeError: 'int' object is not subscriptable

# %% [markdown]
# ### Visualize Python File AST

# %%
# In Jupyter notebook
from IPython.display import Image
import ast
from graphviz import Digraph

def extract_ast(code):
    """Extract abstract syntax tree from Python code"""
    tree = ast.parse(code)
    return tree

def visualize_ast(tree):
    """Create Graphviz visualization of AST"""
    dot = Digraph(comment='AST', node_attr={'shape': 'box', 'style': 'filled', 'fillcolor': '#f0f0f0'})
    
    def add_nodes_edges(node, parent=None):
        node_name = str(id(node))
        label = type(node).__name__
        
        # Add special handling for common node types
        if isinstance(node, ast.ClassDef):
            dot.node(node_name, f"Class: {node.name}", fillcolor='#e0f0e0')
        elif isinstance(node, ast.FunctionDef):
            dot.node(node_name, f"Function: {node.name}", fillcolor='#e0e0f0')
        elif isinstance(node, ast.Name):
            dot.node(node_name, f"Name: {node.id}", fillcolor='#f0e0f0')
        else:
            dot.node(node_name, label)
            
        if parent:
            dot.edge(parent, node_name)
            
        for child in ast.iter_child_nodes(node):
            add_nodes_edges(child, node_name)
            
    add_nodes_edges(tree)
    return dot

# Usage example

# with open('wbfft.py', 'r') as f:
#     code = f.read()

# 1. extract AST
ast_tree = extract_ast(dsp_block_code)
print(ast.dump(ast_tree, indent=4))  # Text representation

# 2. visualize AST
# dot = visualize_ast(ast_tree)
# dot.render('ast_graph', format='png', cleanup=True)  # Save as PNG
# dot  # Display in notebook if using Jupyter

# Image(dot.render(format='png'))
# Out:
# Module(
#     body=[
#         ImportFrom(
#             module='collections',
#             names=[
#                 alias(name='defaultdict')],
#             level=0),
#         Assign(
#             targets=[
#                 Name(id='wideband_fft_top', ctx=Store())],
#             value=Call(
#                 func=Name(id='defaultdict', ctx=Load()),
#                 args=[
#                     Name(id='list', ctx=Load())],
#                 keywords=[])),
#         ClassDef(
#             name='wideband_fft_top',
#             bases=[
#                 Name(id='DSPBlock', ctx=Load())],
#             keywords=[],
#             body=[
#                 FunctionDef(
#                     name='initialize',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(arg='self')],
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         defaults=[]),
#                     body=[
#                         Expr(
#                             value=Constant(value='Initialize method')),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='create_hdl_dir',
#                                     ctx=Load()),
#                                 args=[],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_pkg/fixed_float_types_c.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_pkg/fixed_pkg_c.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_pkg/common_pkg.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_pipeline.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_adder/common_add_sub.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_async.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_areset.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_bit_delay.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_pipeline_sl.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_multiplier/tech_mult_component.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_multiplier/tech_agilex_versal_cmult.vhd'
# )],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_multiplier/tech_complex_mult.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_multiplier/common_complex_mult.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_counter/common_counter.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_delay.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_fifo/common_rl_decrease.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_fifo/common_fifo_rd.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_fifo/tech_fifo_component_pkg.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_fifo/tech_fifo_sc.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_fifo/common_fifo_sc.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/common_ram_pkg.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/tech_memory_component_pkg.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/tech_memory_ram_crw_crw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/tech_memory_ram_cr_cw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/common_ram_crw_crw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/common_paged_ram_crw_crw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/common_paged_ram_rw_rw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/common_paged_ram_r_w.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_requantize/common_round.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_requantize/common_resize.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_requantize/common_requantize.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/tech_memory_rom_r_r.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/tech_memory_rom_r.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/common_rom_r_r.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_pkg/common_str_pkg.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_multiplexer/common_zip.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/r2sdf_fft/twiddlesPkg.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/r2sdf_fft/rTwoBF.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_requantize/r_shift_requantize.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/r2sdf_fft/rTwoWMul.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_r2_bf_par.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_r2_par.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/r2sdf_fft/rTwoBFStage.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/r2sdf_fft/rTwoWeights.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/r2sdf_fft/rTwoSDFStage.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_sepa.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_reorder_sepa_pipe.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_r2_pipe.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_sepa_wide.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_r2_wide.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_wide_unit_control.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_wide_unit.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/mult/ip_cmult_rtl_3dsp.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/mult/ip_cmult_rtl_4dsp.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/fifo/ip_xilinx_fifo_sc.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/ram/ip_xpm_ram_cr_cw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/ram/ip_xpm_ram_crw_crw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/ram/ip_xpm_rom_r.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Name(id='self', ctx=Load()),
#                                     attr='add_source',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/ram/ip_xpm_rom_r_r.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='common_pkg_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_pkg/fixed_float_types_c.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='common_pkg_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_pkg/fixed_pkg_c.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='common_pkg_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_pkg/common_pkg.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='common_components_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_pipeline.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_adder_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_adder/common_add_sub.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='common_components_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_async.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='common_components_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_areset.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='common_components_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_bit_delay.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='common_components_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_pipeline_sl.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_multiplier_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_multiplier/tech_mult_component.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_multiplier_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_multiplier/tech_agilex_versal_cmult.vhd'
# )],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_multiplier_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_multiplier/tech_complex_mult.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_multiplier_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_multiplier/common_complex_mult.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_counter_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_counter/common_counter.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='common_components_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/common_components/common_delay.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_fifo_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_fifo/common_rl_decrease.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_fifo_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_fifo/common_fifo_rd.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_fifo_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_fifo/tech_fifo_component_pkg.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_fifo_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_fifo/tech_fifo_sc.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_fifo_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_fifo/common_fifo_sc.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_ram_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/common_ram_pkg.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_ram_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/tech_memory_component_pkg.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_ram_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/tech_memory_ram_crw_crw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_ram_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/tech_memory_ram_cr_cw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_ram_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_ram/common_ram_crw_crw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_ram_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
# ...
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/r2sdf_fft/rTwoBF.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_requantize_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_requantize/r_shift_requantize.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='r2sdf_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/r2sdf_fft/rTwoWMul.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_wb_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_r2_bf_par.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_wb_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_r2_par.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='r2sdf_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/r2sdf_fft/rTwoBFStage.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='r2sdf_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/r2sdf_fft/rTwoWeights.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='r2sdf_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/r2sdf_fft/rTwoSDFStage.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_wb_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_sepa.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_wb_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_reorder_sepa_pipe.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_wb_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_r2_pipe.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_wb_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_sepa_wide.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_wb_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_r2_wide.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_wb_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_wide_unit_control.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='casper_wb_fft_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/casper_wb_fft/fft_wide_unit.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='ip_xpm_mult_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/mult/ip_cmult_rtl_3dsp.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='ip_xpm_mult_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/mult/ip_cmult_rtl_4dsp.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='ip_xpm_fifo_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/fifo/ip_xilinx_fifo_sc.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='ip_xpm_ram_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/ram/ip_xpm_ram_cr_cw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='ip_xpm_ram_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/ram/ip_xpm_ram_crw_crw.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='ip_xpm_ram_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/ram/ip_xpm_rom_r.vhd')],
#                                 keywords=[])),
#                         Expr(
#                             value=Call(
#                                 func=Attribute(
#                                     value=Subscript(
#                                         value=Name(id='wideband_fft_top_libs', ctx=Load()),
#                                         slice=Constant(value='ip_xpm_ram_lib'),
#                                         ctx=Load()),
#                                     attr='append',
#                                     ctx=Load()),
#                                 args=[
#                                     Constant(value='casper_dspdevel/ip_xpm/ram/ip_xpm_rom_r_r.vhd')],
#                                 keywords=[]))],
#                     decorator_list=[]),
#                 FunctionDef(
#                     name='modify_top',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(arg='self')],
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         defaults=[]),
#                     body=[
#                         Expr(
#                             value=Constant(value='Modify Top method')),
#                         Pass()],
#                     decorator_list=[]),
#                 FunctionDef(
#                     name='_generate_hdl_wrapper',
#                     args=arguments(
#                         posonlyargs=[],
#                         args=[
#                             arg(arg='self')],
#                         kwonlyargs=[],
#                         kw_defaults=[],
#                         defaults=[]),
#                     body=[
#                         Expr(
#                             value=Constant(value=' Generate Hdl Wrapper method')),
#                         Pass()],
#                     decorator_list=[])],
#             decorator_list=[])],
#     type_ignores=[])
